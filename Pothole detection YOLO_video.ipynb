# %%
# 내 구글 드라이브에 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 필요한 패키지와 모듈을 불러옴
import cv2
import numpy as np
import time
import io
import base64
from IPython.display import HTML

# %%
# Detection 하기 전에 원본 동영상을 Display
video = io.open('/content/gdrive/MyDrive/Pothole_Detection/pothole.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video width="50%" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4"/>
             </video>'''.format(encoded.decode('ascii')))

# %%
file_name = '/content/gdrive/MyDrive/Pothole_Detection/pothole.mp4'  # Detection 할 원본 동영상
min_confidence = 0.2   # detection 으로 인정할 최소 확률(신뢰도) 지정
nms_threshold = 0.4    # non-max suppression threshold
output_name = 'pothole_output_video.mp4'  # Detection 된 output 동영상 
elapsed_time = 0       # 총 경과시간 초기화

# %%
def detectAndDisplay(frame):
    start_time = time.time()
    img = cv2.resize(frame, None, fx=0.9, fy=0.9)
    height, width, channels = img.shape

    # YOLOv3의 Detecting model 3가지(320×320, 416×416, 608×608)
    blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), swapRB=True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)

    # Showing informations on the screen
    class_ids = []      # detection 한 Class id를 저장하는 배열 정의
    confidences = []    # detection 한 Class 의 신뢰도(확률)를 저장하는 배열 정의
    boxes = []          # detection 한 boxing 정보를 저장하는 배열 정의
    colors = []        # detection 한 Class id 마다 다른 컬러를 지정하는 배열 정의

    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)      # detection 한 Class id
            confidence = scores[class_id]     # detection 한 Class 의 신뢰도(확률)
            if confidence > min_confidence:
                # Object detected
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # Rectangle coordinates
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])             # boxing 정보를 boxes 배열에 저장
                confidences.append(float(confidence))  # 신뢰도(확률)을 confidences 배열에 저장
                class_ids.append(class_id)             # Class id 를 class_ids 배열에 저장
                colors.append(color_lists[class_id])   # Class id 마다 다른 컬러를 배열에 저장
    
    # apply non-max suppression
    indexes = cv2.dnn.NMSBoxes(boxes, confidences, min_confidence, nms_threshold)    # 박스안에 박스(노이즈)를 하나로 만들어 준다.
    font = cv2.FONT_HERSHEY_PLAIN
    for i in range(len(boxes)):
        if i in indexes:    # 노이즈가 제거된 박스만 표시해 준다.   
            x, y, w, h = boxes[i]
            label = "{}: {:.2f}".format(classes[class_ids[i]], confidences[i]*100)    # Class 이름, 신뢰도(확률) 표시 
            print(i, label)
            color = colors[i]
            cv2.rectangle(img, (x, y), (x + w, y + h), color, 1)
            cv2.rectangle(img, (x, y - 25), (x + w, y), color, -1)
            cv2.putText(img, label, (x + 2, y - 10), font, 1, (255, 255, 255), 1)
            
    process_time = time.time() - start_time
    global elapsed_time
    elapsed_time += process_time   # 총 경과시간 누적
    print("=== A frame took {:.3f} seconds".format(process_time))

    # video 를 disk 에 output 하기 위해 writer 를 초기화한다.
    global writer
    if writer is None and output_name is not None:
        fourcc = cv2.VideoWriter_fourcc(*"DIVX")
        writer = cv2.VideoWriter(output_name, fourcc, 30,
                (img.shape[1], img.shape[0]), True)
        
    # disk 에 frame 을 write 합니다.
    if writer is not None:
        writer.write(img)

# %%
# Load YOLO
net = cv2.dnn.readNet("/content/gdrive/MyDrive/Pothole_Detection/backup/custom-train-yolo3_last.weights", "/content/gdrive/MyDrive/Pothole_Detection/custom/custom-test-yolo3.cfg")
classes = []   # detection 할 Object(Class) list 배열을 정의
with open("/content/gdrive/MyDrive/Pothole_Detection/custom/classes.names", "r") as f:
   classes = [line.strip() for line in f.readlines()]   # 80개의 Object(class)를 구분할 수 있는 Object의 이름을 classes 배열에 넣어준다.
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
color_lists = np.random.uniform(0, 255, size=(len(classes), 3))  # Object 마다 컬러를 하나씩 다르게 지정

# 원본 동영상에서 video stream을 읽어온다.
cap = cv2.VideoCapture(file_name)
writer = None
if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)
while True:
    ret, frame = cap.read()
    if frame is None:
        # close the video file pointers
        cap.release()
        # close the writer point
        writer.release()
        print('--(!) No captured frame -- Break!')
        print("elapsed time {:.3f} seconds".format(elapsed_time))
        break
    detectAndDisplay(frame)
# Out:
# === A frame took 1.001 seconds
# === A frame took 0.852 seconds
# === A frame took 0.849 seconds
# === A frame took 0.838 seconds
# === A frame took 0.840 seconds
# === A frame took 0.862 seconds
# 0 pothole: 25.63
# === A frame took 0.843 seconds
# 0 pothole: 29.00
# === A frame took 0.853 seconds
# 0 pothole: 33.04
# === A frame took 0.849 seconds
# 0 pothole: 22.90
# === A frame took 0.845 seconds
# === A frame took 0.865 seconds
# 0 pothole: 27.12
# === A frame took 0.899 seconds
# === A frame took 0.844 seconds
# 0 pothole: 32.43
# === A frame took 0.877 seconds
# 0 pothole: 21.09
# === A frame took 0.847 seconds
# 0 pothole: 22.40
# === A frame took 0.843 seconds
# 1 pothole: 24.60
# === A frame took 0.875 seconds
# 0 pothole: 37.95
# === A frame took 0.853 seconds
# 0 pothole: 29.77
# === A frame took 0.846 seconds
# 0 pothole: 21.00
# === A frame took 0.854 seconds
# 0 pothole: 26.50
# === A frame took 0.842 seconds
# 0 pothole: 30.50
# === A frame took 0.844 seconds
# 0 pothole: 31.99
# === A frame took 0.844 seconds
# 0 pothole: 27.34
# === A frame took 0.838 seconds
# 0 pothole: 39.26
# === A frame took 0.845 seconds
# 1 pothole: 23.36
# === A frame took 0.878 seconds
# 1 pothole: 25.90
# === A frame took 0.871 seconds
# 0 pothole: 31.04
# === A frame took 0.838 seconds
# 1 pothole: 30.64
# === A frame took 0.846 seconds
# 0 pothole: 29.23
# === A frame took 0.860 seconds
# 0 pothole: 42.28
# === A frame took 0.842 seconds
# 0 pothole: 50.27
# === A frame took 0.853 seconds
# 1 pothole: 46.78
# === A frame took 0.847 seconds
# 1 pothole: 51.39
# === A frame took 0.840 seconds
# 1 pothole: 58.44
# === A frame took 0.858 seconds
# 1 pothole: 56.88
# === A frame took 0.855 seconds
# 1 pothole: 64.49
# === A frame took 0.858 seconds
# 1 pothole: 54.02
# === A frame took 0.855 seconds
# 1 pothole: 74.61
# === A frame took 0.864 seconds
# 1 pothole: 57.05
# === A frame took 0.858 seconds
# 1 pothole: 61.25
# === A frame took 0.862 seconds
# 1 pothole: 65.37
# === A frame took 0.852 seconds
# 1 pothole: 48.28
# === A frame took 0.864 seconds
# 1 pothole: 39.57
# === A frame took 0.859 seconds
# 0 pothole: 30.50
# === A frame took 0.850 seconds
# 0 pothole: 47.40
# === A frame took 0.880 seconds
# 0 pothole: 34.32
# === A frame took 0.866 seconds
# 1 pothole: 38.74
# === A frame took 0.856 seconds
# 1 pothole: 57.51
# === A frame took 0.850 seconds
# 1 pothole: 58.29
# === A frame took 0.858 seconds
# 1 pothole: 65.71
# === A frame took 0.838 seconds
# 1 pothole: 59.10
# === A frame took 0.853 seconds
# 0 pothole: 45.33
# === A frame took 0.848 seconds
# 0 pothole: 27.41
# === A frame took 0.840 seconds
# 0 pothole: 28.51
# === A frame took 0.855 seconds
# 1 pothole: 53.60
# === A frame took 0.888 seconds
# 0 pothole: 50.94
# === A frame took 0.851 seconds
# 0 pothole: 57.94
# === A frame took 0.851 seconds
# 0 pothole: 25.79
# === A frame took 0.851 seconds
# === A frame took 0.849 seconds
# === A frame took 0.850 seconds
# === A frame took 0.857 seconds
# === A frame took 0.845 seconds
# === A frame took 0.847 seconds
# === A frame took 0.854 seconds
# === A frame took 0.857 seconds
# === A frame took 0.838 seconds
# 0 pothole: 48.96
# === A frame took 0.849 seconds
# 0 pothole: 33.56
# === A frame took 0.849 seconds
# 0 pothole: 43.70
# === A frame took 0.871 seconds
# 1 pothole: 53.51
# === A frame took 0.854 seconds
# 1 pothole: 47.07
# === A frame took 0.840 seconds
# 1 pothole: 39.69
# === A frame took 0.848 seconds
# 1 pothole: 60.70
# === A frame took 0.861 seconds
# 1 pothole: 47.68
# === A frame took 0.857 seconds
# 1 pothole: 40.96
# === A frame took 0.839 seconds
# 1 pothole: 44.50
# === A frame took 0.855 seconds
# 1 pothole: 55.55
# === A frame took 0.854 seconds
# 1 pothole: 53.49
# === A frame took 0.849 seconds
# 1 pothole: 55.54
# === A frame took 0.861 seconds
# 0 pothole: 57.89
# === A frame took 0.857 seconds
# 0 pothole: 49.10
# === A frame took 0.885 seconds
# 0 pothole: 30.29
# === A frame took 0.889 seconds
# 0 pothole: 44.31
# === A frame took 0.847 seconds
# 0 pothole: 53.30
# === A frame took 0.842 seconds
# 0 pothole: 47.47
# === A frame took 0.863 seconds
# 0 pothole: 52.50
# === A frame took 0.919 seconds
# 0 pothole: 57.78
# === A frame took 0.898 seconds
# 0 pothole: 51.50
# === A frame took 0.897 seconds
# 0 pothole: 57.10
# === A frame took 0.863 seconds
# 0 pothole: 51.85
# === A frame took 0.840 seconds
# 0 pothole: 53.07
# === A frame took 0.843 seconds
# 0 pothole: 68.47
# === A frame took 0.859 seconds
# 0 pothole: 54.98
# === A frame took 0.897 seconds
# 0 pothole: 58.18
# === A frame took 0.892 seconds
# 0 pothole: 59.56
# === A frame took 0.849 seconds
# 0 pothole: 61.64
# === A frame took 0.844 seconds
# 0 pothole: 60.53
# === A frame took 0.848 seconds
# 0 pothole: 57.43
# === A frame took 0.858 seconds
# 0 pothole: 61.97
# === A frame took 0.850 seconds
# 1 pothole: 63.34
# === A frame took 0.850 seconds
# 0 pothole: 57.28
# === A frame took 0.853 seconds
# 0 pothole: 54.03
# === A frame took 0.843 seconds
# 0 pothole: 63.11
# === A frame took 0.840 seconds
# 0 pothole: 73.35
# === A frame took 0.853 seconds
# 0 pothole: 74.21
# === A frame took 0.845 seconds
# 0 pothole: 72.76
# === A frame took 0.839 seconds
# 0 pothole: 71.73
# === A frame took 0.847 seconds
# 0 pothole: 69.91
# === A frame took 0.851 seconds
# 0 pothole: 69.22
# === A frame took 0.867 seconds
# 0 pothole: 70.18
# === A frame took 0.842 seconds
# 0 pothole: 62.68
# === A frame took 0.857 seconds
# 0 pothole: 60.62
# === A frame took 0.856 seconds
# 0 pothole: 50.40
# === A frame took 0.853 seconds
# 1 pothole: 46.10
# === A frame took 0.845 seconds
# 0 pothole: 58.62
# === A frame took 0.853 seconds
# 1 pothole: 58.77
# === A frame took 0.851 seconds
# 1 pothole: 61.01
# === A frame took 0.857 seconds
# 0 pothole: 65.30
# === A frame took 0.847 seconds
# 1 pothole: 59.13
# === A frame took 0.844 seconds
# 1 pothole: 53.90
# === A frame took 0.848 seconds
# 1 pothole: 64.10
# === A frame took 0.853 seconds
# 1 pothole: 68.33
# === A frame took 0.905 seconds
# 1 pothole: 57.86
# === A frame took 0.859 seconds
# 0 pothole: 57.61
# === A frame took 0.842 seconds
# 0 pothole: 51.39
# === A frame took 0.861 seconds
# 0 pothole: 69.53
# === A frame took 0.866 seconds
# 0 pothole: 61.49
# === A frame took 0.873 seconds
# 0 pothole: 55.62
# === A frame took 0.862 seconds
# 0 pothole: 39.10
# === A frame took 0.869 seconds
# 0 pothole: 25.44
# === A frame took 0.858 seconds
# === A frame took 0.877 seconds
# === A frame took 0.870 seconds
# === A frame took 0.854 seconds
# === A frame took 0.884 seconds
# === A frame took 0.859 seconds
# === A frame took 0.857 seconds
# === A frame took 0.861 seconds
# === A frame took 0.866 seconds
# === A frame took 0.850 seconds
# === A frame took 0.850 seconds
# === A frame took 0.850 seconds
# === A frame took 0.850 seconds
# === A frame took 0.849 seconds
# === A frame took 0.851 seconds
# === A frame took 0.844 seconds
# === A frame took 0.853 seconds
# === A frame took 0.880 seconds
# === A frame took 0.835 seconds
# === A frame took 0.846 seconds
# === A frame took 0.852 seconds
# === A frame took 0.917 seconds
# === A frame took 0.845 seconds
# === A frame took 0.844 seconds
# === A frame took 0.852 seconds
# === A frame took 0.838 seconds
# === A frame took 0.857 seconds
# 0 pothole: 40.27
# === A frame took 0.846 seconds
# 0 pothole: 42.72
# === A frame took 0.844 seconds
# 0 pothole: 31.01
# === A frame took 0.846 seconds
# 0 pothole: 35.13
# === A frame took 0.843 seconds
# 0 pothole: 51.61
# === A frame took 0.854 seconds
# 0 pothole: 51.23
# === A frame took 0.850 seconds
# 0 pothole: 54.57
# === A frame took 0.890 seconds
# 0 pothole: 67.02
# === A frame took 0.855 seconds
# 1 pothole: 65.75
# === A frame took 0.866 seconds
# 1 pothole: 74.88
# === A frame took 0.848 seconds
# 1 pothole: 74.48
# === A frame took 0.848 seconds
# 0 pothole: 63.44
# === A frame took 0.861 seconds
# 1 pothole: 74.55
# === A frame took 0.885 seconds
# 1 pothole: 79.07
# === A frame took 0.847 seconds
# 1 pothole: 77.21
# === A frame took 0.847 seconds
# 0 pothole: 74.07
# === A frame took 0.847 seconds
# 0 pothole: 78.22
# === A frame took 0.853 seconds
# 0 pothole: 76.43
# === A frame took 0.844 seconds
# 0 pothole: 78.08
# === A frame took 0.850 seconds
# 0 pothole: 83.20
# === A frame took 0.868 seconds
# 0 pothole: 80.79
# === A frame took 0.847 seconds
# 0 pothole: 85.12
# === A frame took 0.841 seconds
# 0 pothole: 82.91
# === A frame took 0.846 seconds
# 0 pothole: 84.63
# === A frame took 0.852 seconds
# 0 pothole: 79.93
# === A frame took 0.861 seconds
# 0 pothole: 78.72
# === A frame took 0.853 seconds
# 0 pothole: 83.98
# === A frame took 0.854 seconds
# 0 pothole: 90.28
# === A frame took 0.856 seconds
# 0 pothole: 86.93
# === A frame took 0.855 seconds
# 0 pothole: 79.18
# === A frame took 0.850 seconds
# 1 pothole: 66.22
# === A frame took 0.840 seconds
# 0 pothole: 80.64
# === A frame took 0.846 seconds
# 0 pothole: 57.63
# === A frame took 0.838 seconds
# 0 pothole: 20.99
# === A frame took 0.840 seconds
# === A frame took 0.849 seconds
# === A frame took 0.859 seconds
# === A frame took 0.839 seconds
# === A frame took 0.841 seconds
# === A frame took 0.838 seconds
# === A frame took 0.854 seconds
# === A frame took 0.848 seconds
# === A frame took 0.852 seconds
# === A frame took 0.855 seconds
# === A frame took 0.843 seconds
# === A frame took 0.846 seconds
# === A frame took 0.853 seconds
# === A frame took 0.862 seconds
# === A frame took 0.856 seconds
# === A frame took 0.862 seconds
# === A frame took 0.860 seconds
# === A frame took 0.855 seconds
# === A frame took 0.979 seconds
# === A frame took 0.857 seconds
# === A frame took 0.835 seconds
# === A frame took 0.846 seconds
# === A frame took 0.871 seconds
# === A frame took 0.841 seconds
# === A frame took 0.838 seconds
# === A frame took 0.846 seconds
# === A frame took 0.841 seconds
# === A frame took 0.856 seconds
# 0 pothole: 22.30
# === A frame took 0.847 seconds
# 0 pothole: 25.47
# === A frame took 0.847 seconds
# 1 pothole: 31.36
# === A frame took 0.886 seconds
# 0 pothole: 46.83
# === A frame took 0.851 seconds
# 1 pothole: 47.39
# === A frame took 0.861 seconds
# 1 pothole: 50.00
# === A frame took 0.857 seconds
# 1 pothole: 64.58
# === A frame took 0.855 seconds
# 1 pothole: 69.88
# === A frame took 0.863 seconds
# 1 pothole: 76.31
# === A frame took 0.855 seconds
# 1 pothole: 79.62
# === A frame took 0.861 seconds
# 1 pothole: 84.97
# === A frame took 0.854 seconds
# 1 pothole: 74.69
# === A frame took 0.859 seconds
# 1 pothole: 71.45
# === A frame took 0.859 seconds
# 1 pothole: 73.19
# === A frame took 0.865 seconds
# 1 pothole: 65.51
# === A frame took 0.901 seconds
# 1 pothole: 66.85
# === A frame took 0.856 seconds
# 1 pothole: 56.72
# === A frame took 0.849 seconds
# 1 pothole: 57.50
# === A frame took 0.848 seconds
# 1 pothole: 68.85
# === A frame took 0.865 seconds
# 1 pothole: 71.74
# === A frame took 0.852 seconds
# 1 pothole: 59.85
# === A frame took 0.859 seconds
# 1 pothole: 48.07
# === A frame took 0.897 seconds
# 0 pothole: 45.14
# === A frame took 0.854 seconds
# 0 pothole: 38.86
# === A frame took 0.846 seconds
# 0 pothole: 38.86
# === A frame took 0.841 seconds
# 0 pothole: 61.21
# === A frame took 0.837 seconds
# 1 pothole: 52.89
# === A frame took 0.844 seconds
# 1 pothole: 48.61
# === A frame took 0.883 seconds
# 0 pothole: 51.18
# === A frame took 0.857 seconds
# 0 pothole: 49.37
# === A frame took 0.842 seconds
# === A frame took 0.840 seconds
# === A frame took 0.840 seconds
# === A frame took 0.845 seconds
# === A frame took 0.843 seconds
# === A frame took 0.857 seconds
# === A frame took 0.865 seconds
# === A frame took 0.847 seconds
# === A frame took 0.845 seconds
# === A frame took 0.843 seconds
# === A frame took 0.844 seconds
# === A frame took 0.854 seconds
# === A frame took 0.858 seconds
# === A frame took 0.847 seconds
# === A frame took 0.847 seconds
# === A frame took 0.839 seconds
# === A frame took 0.848 seconds
# === A frame took 0.844 seconds
# === A frame took 0.859 seconds
# === A frame took 0.849 seconds
# === A frame took 0.849 seconds
# === A frame took 0.846 seconds
# === A frame took 0.855 seconds
# === A frame took 0.848 seconds
# 0 pothole: 26.09
# === A frame took 0.853 seconds
# 0 pothole: 36.92
# === A frame took 0.860 seconds
# 0 pothole: 66.77
# === A frame took 0.863 seconds
# 1 pothole: 24.75
# === A frame took 0.849 seconds
# 0 pothole: 59.93
# === A frame took 0.855 seconds
# 1 pothole: 57.80
# === A frame took 0.878 seconds
# 1 pothole: 65.86
# === A frame took 0.867 seconds
# 0 pothole: 75.85
# === A frame took 0.852 seconds
# 0 pothole: 83.11
# === A frame took 0.853 seconds
# 1 pothole: 85.04
# === A frame took 0.853 seconds
# 1 pothole: 81.08
# === A frame took 0.850 seconds
# 1 pothole: 76.17
# === A frame took 0.851 seconds
# 1 pothole: 75.21
# === A frame took 0.916 seconds
# 1 pothole: 74.39
# === A frame took 0.868 seconds
# 1 pothole: 76.31
# === A frame took 0.854 seconds
# 1 pothole: 75.18
# === A frame took 0.845 seconds
# 1 pothole: 75.38
# === A frame took 0.853 seconds
# 0 pothole: 73.16
# === A frame took 0.853 seconds
# 0 pothole: 54.91
# === A frame took 0.888 seconds
# === A frame took 0.840 seconds
# === A frame took 0.844 seconds
# === A frame took 0.849 seconds
# === A frame took 0.850 seconds
# === A frame took 0.842 seconds
# === A frame took 0.849 seconds
# === A frame took 0.854 seconds
# === A frame took 0.848 seconds
# === A frame took 0.855 seconds
# === A frame took 0.851 seconds
# === A frame took 0.866 seconds
# === A frame took 0.891 seconds
# === A frame took 0.920 seconds
# === A frame took 0.835 seconds
# === A frame took 0.846 seconds
# === A frame took 0.848 seconds
# === A frame took 0.844 seconds
# === A frame took 0.836 seconds
# === A frame took 0.844 seconds
# --(!) No captured frame -- Break!
# elapsed time 264.452 seconds
